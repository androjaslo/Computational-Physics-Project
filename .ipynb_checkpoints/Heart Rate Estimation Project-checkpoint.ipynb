# %% [markdown]
# # Intro

# %% [markdown]
# The human body constantly emmits life signs that can be detected with inertial sensors, such as accelerometers, gyroscopes, and magnetometers. In practice, these sensors are integrated through a device called an Inertial Measurement Unit (IMU) that allows, for example, tracing the heart activity thanks to small body movements caused by the contraction and relaxation of the heart.
#
# This way to monitor the heart is known as ballistocardiography (BCG) or seismocardiography (SCG). In simple terms, BCG and SCG are both are non-invasive techniques used to monitor the human heart, based on its mechanical activity. These techniques record the micromovements induced by cardiovascular activity at the body’s center of mass and on the chest.
#
# <center>
#   <img src="example.png" width="40%">
# </center>
#
# **Sources:**
#
# * Haescher, M., Matthies, D. J., Trimpop, J., & Urban, B. (2015, June). A study on measuring heart-and respiration-rate via wrist-worn accelerometer-based seismocardiography (SCG) in comparison to commonly applied technologies. In Proceedings of the 2nd international Workshop on Sensor-based Activity Recognition and Interaction (pp. 1-6).
#
# * Balali, P., Rabineau, J., Hossein, A., Tordeur, C., Debeir, O., & Van De Borne, P. (2022). Investigating cardiorespiratory interaction using ballistocardiography and seismocardiography—a narrative review. Sensors, 22(23), 9565.

# %% [markdown]
# In the following project, we estimate the heart rate of a healthy subject (or two?), by blablabla
#
# The measurements were done by using a MuSe (Multi-Sensor miniaturized, low-power, wireless IMU), which recorded all the inertial data necessary for the estimation of SCG and BCG.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Center Sternum

# %%
cs=pd.read_csv('center_sternum.txt', sep='\t')
cs
# Out:
#        Log Mode  Log Freq   Timestamp     AccX     AccY    AccZ      GyroX  \
# 0             5       200  1576222772  947.086  435.662  70.638  -6.824428
# 1             5       200  1576222772  969.168  387.777  88.877   6.183206
# 2             5       200  1576222772  989.603  380.335  78.751  11.709920
# 3             5       200  1576222772  954.894  418.033  88.328  17.877860
# 4             5       200  1576222772  972.096  427.732  99.857  25.221370
# ...         ...       ...         ...      ...      ...     ...        ...
# 16501         5       200  1576222847  958.493  291.092 -54.290   1.664122
# 16502         5       200  1576222847  954.650  288.042 -49.654   1.480916
# 16503         5       200  1576222847  967.338  290.482 -63.867   1.114504
# 16504         5       200  1576222847  965.630  300.852 -56.242   0.702290
# 16505         5       200  1576222847  959.957  298.473 -55.998   0.290076
#
# ...

# %% [markdown]
# Because the most common wearable systems for detecting muscle activity are based on accelerometry (Haescher, 2015)...
# ( Lets do a correlation matrix to justify which variables are we going to use)

# %%
cs = cs[['Timestamp', 'AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY',	'GyroZ']].copy()
#cs

# %%
import datetime # The datetime module supplies classes for manipulating dates and times

ts = 1555415326 # 2019-04-16 13:48:46
#ts = 1555415469	# 2019-04-16 13:51:09
fecha = datetime.datetime.fromtimestamp(ts)
# fromtimestamp() Function Of Datetime.date Class In Python. 
# fromtimestamp() function in Python is used to return the date corresponding to a specified timestamp.

# I read and there are different types of timestamps.
# Apparently the one we have is in a format called unix time stamp.
# Basically is a way to track time as a running total of seconds. The count starts on January 1st, 1970 at UTC

# To be sure we print the date and it is indeed the same it is in the README file.
print(fecha)
# Out:
# 2019-04-16 13:48:46

# %% [markdown]
# # freq check and time

# %%
conteos = cs['Timestamp'].value_counts()
print(conteos)
# Out:
# Timestamp
# 1576222772    224
# 1576222774    224
# 1576222778    224
# 1576222776    224
# 1576222783    224
#              ...
# 1576222834    210
# 1576222841    210
# 1576222844    210
# 1576222846    210
# 1576222847    182
# Name: count, Length: 76, dtype: int64

# %%
freq = cs['Timestamp'].value_counts().mean()
freq
# Out:
# np.float64(217.18421052631578)

# %%
cs['Time'] = np.arange(len(cs))/freq # numero de la muestra / frequencia 
cs
# Out:
#         Timestamp     AccX     AccY    AccZ      GyroX      GyroY     GyroZ  \
# 0      1576222772  947.086  435.662  70.638  -6.824428 -14.244280  1.404580
# 1      1576222772  969.168  387.777  88.877   6.183206 -12.290080 -7.969466
# 2      1576222772  989.603  380.335  78.751  11.709920  -4.961832 -7.450382
# 3      1576222772  954.894  418.033  88.328  17.877860   2.519084 -5.984733
# 4      1576222772  972.096  427.732  99.857  25.221370   5.404580  4.015267
# ...           ...      ...      ...     ...        ...        ...       ...
# 16501  1576222847  958.493  291.092 -54.290   1.664122   2.305344 -0.671756
# 16502  1576222847  954.650  288.042 -49.654   1.480916   2.488550 -0.702290
# 16503  1576222847  967.338  290.482 -63.867   1.114504   3.374046 -0.900763
# 16504  1576222847  965.630  300.852 -56.242   0.702290   3.664122 -1.587786
# 16505  1576222847  959.957  298.473 -55.998   0.290076   4.061069 -1.343511
#
#             Time
# 0       0.000000
# 1       0.004604
# ...

# %% [markdown]
# # Center sternum calibration

# %%
import numpy as np

A = np.array([
    [1.000966,    -0.002326418, -0.0006995499],
    [-0.002326379, 0.9787045,   -0.001540918],
    [-0.0006995811, -0.001540928, 1.00403]
])

Acc_offset = np.array([-3.929942, -13.74679, 60.67546])
Gyro_offset = np.array([-2.242224, 2.963463, -0.718397])

Acc_raw_data = cs[['AccX', 'AccY', 'AccZ']].values
Gyro_raw_data = cs[['GyroX', 'GyroY', 'GyroZ']].values

Acc_calibrated_data = (Acc_raw_data - Acc_offset) @ A.T
Gyro_calibrated_data = (Gyro_raw_data - Gyro_offset)

cs[['AccX_cal', 'AccY_cal', 'AccZ_cal']] = Acc_calibrated_data 
cs[['GyroX_cal', 'GyroY_cal', 'GyroZ_cal']] = Gyro_calibrated_data

#cs

# %%
plt.figure(figsize=(16, 8))
plt.plot(cs['AccX_cal'],label='AccX_cal')
plt.plot(cs['AccY_cal'],label='AccY_cal')
plt.plot(cs['AccZ_cal'],label='AccZ_cal')
plt.plot(cs['AccX'],label='AccX')
plt.plot(cs['AccY'],label='AccY')
plt.plot(cs['AccZ'],label='AccZ')
plt.legend()

# %% [raw]
# The initial and terminal spikes in the accelerometer data likely represent motion artifacts from when the sensor was first attached and finally removed. For that reason, we plot a zoom...

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(16, 8))

ax1.plot(cs["AccX_cal"][:1500])
ax2.plot(cs["AccY_cal"][:1500])
ax3.plot(cs["AccZ_cal"][:1500])

ax4.plot(cs["AccX_cal"][-1500:])
ax5.plot(cs["AccY_cal"][-1500:])
ax6.plot(cs["AccZ_cal"][-1500:])

plt.show()

# %% [markdown]
# After zooming into these specific regions, we decided to exclude the first and last 200 data points...

# %%
cs_clean = cs[1000:-2000].copy()
cs_clean = cs_clean.drop(['AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY',	'GyroZ'], axis=1)
cs_clean
# Out:
#         Timestamp       Time   AccX_cal    AccY_cal     AccZ_cal  GyroX_cal  \
# 1000   1576222776   4.604386 -40.098619  149.496490 -1017.661849   2.913980
# 1001   1576222776   4.608991 -41.489264  144.128734 -1018.999816   3.127720
# 1002   1576222776   4.613595 -40.763430  146.152352 -1016.063724   3.692606
# 1003   1576222776   4.618199 -44.917316  145.797780 -1012.140525   3.845277
# 1004   1576222776   4.622804 -62.408146  151.237974  -990.517096   3.830010
# ...           ...        ...        ...         ...          ...        ...
# 14501  1576222838  66.768206  19.515217  138.660326 -1010.398420   2.425430
# 14502  1576222838  66.772810  14.427445  142.109100  -993.680219   3.219323
# 14503  1576222838  66.777414  24.190523  151.254483 -1015.749927   5.005583
# 14504  1576222838  66.782019  18.236886  161.822537 -1007.432992   5.677339
# 14505  1576222838  66.786623  16.542752  156.219413 -1010.546499   5.204056
#
#        GyroY_cal  GyroZ_cal
# ...

# %% [markdown]
# # Center sternum magnitudes of Acc and Gyro

# %% [markdown]
# Following Haescher(2015), a combined signal from the three axes was generated by computing the magnitude of the acceleration vector: $$a= \sqrt{a_x^2 + a_y^2 +az^2}$$

# %%
cs_clean['Acc'] = np.sqrt(cs_clean['AccX_cal']**2 + cs_clean['AccY_cal']**2 + cs_clean['AccZ_cal']**2)
cs_clean['Gyro'] = np.sqrt(cs_clean['GyroX_cal']**2 + cs_clean['GyroY_cal']**2 + cs_clean['GyroZ_cal']**2)
cs_clean
# Out:
#         Timestamp       Time   AccX_cal    AccY_cal     AccZ_cal  GyroX_cal  \
# 1000   1576222776   4.604386 -40.098619  149.496490 -1017.661849   2.913980
# 1001   1576222776   4.608991 -41.489264  144.128734 -1018.999816   3.127720
# 1002   1576222776   4.613595 -40.763430  146.152352 -1016.063724   3.692606
# 1003   1576222776   4.618199 -44.917316  145.797780 -1012.140525   3.845277
# 1004   1576222776   4.622804 -62.408146  151.237974  -990.517096   3.830010
# ...           ...        ...        ...         ...          ...        ...
# 14501  1576222838  66.768206  19.515217  138.660326 -1010.398420   2.425430
# 14502  1576222838  66.772810  14.427445  142.109100  -993.680219   3.219323
# 14503  1576222838  66.777414  24.190523  151.254483 -1015.749927   5.005583
# 14504  1576222838  66.782019  18.236886  161.822537 -1007.432992   5.677339
# 14505  1576222838  66.786623  16.542752  156.219413 -1010.546499   5.204056
#
#        GyroY_cal  GyroZ_cal          Acc      Gyro
# ...

# %% [markdown]
# # FFT - Center sternum

# %%
from scipy import fft

dt = 1/200

cs_fft = fft.fft(cs_clean['Acc'].values, axis=0)
freqs = fft.fftfreq(np.array(cs_clean['Acc']).size,d=dt)

#mask = (freqs > 0.5) & (freqs < 10)
mask = freqs > 0
f_plot = freqs[mask]
p_plot = np.abs(cs_fft[mask])

plt.plot(f_plot, p_plot, color='black')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.grid()
plt.show()

# %%
def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

# %%
from scipy import fft

dt = 1/200
window_size = 10 

acc_smooth = moving_average(cs_clean['Acc'].values, window_size)

cs_fft = fft.fft(acc_smooth, axis=0)
freqs = fft.fftfreq(acc_smooth.size, d=dt)

mask = (freqs > 0) & (freqs < 10)
#mask = freqs > 0
f_plot = freqs[mask]
p_plot = np.abs(cs_fft[mask])

plt.plot(f_plot, p_plot)
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.grid()
plt.show()

# %% [markdown]
# # HERE STARTS THE SAME PROCESS BUT FOR CHEST SWEATER

# %%
chest=pd.read_csv('4_Chest_sweater.txt', sep='\t')
chest
# Out:
#        Log Mode  Log Freq   Timestamp     AccX     AccY     AccZ      GyroX  \
# 0             5       100  1555414552  687.836  380.823  580.354  -7.926829
# 1             5       100  1555414552 -812.703 -108.946  726.876 -11.707320
# 2             5       100  1555414552 -812.520 -108.824  733.952 -37.073170
# 3             5       100  1555414552 -787.144  -45.628  616.954 -56.341460
# 4             5       100  1555414552 -800.259 -137.433  411.689  -1.097561
# ...         ...       ...         ...      ...      ...      ...        ...
# 14933         5       100  1555415471 -890.722  -81.008  446.764  -2.682927
# 14934         5       100  1555415471 -885.964  -76.006  459.025  -3.902439
# 14935         5       100  1555415471 -879.681  -77.714  475.068  -3.048780
# 14936         5       100  1555415471 -894.992  -76.311  502.701   0.121951
# 14937         5       100  1555415471 -889.319  -90.951  471.835   3.536585
#
# ...

# %%
chest = chest[['Timestamp', 'AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY',	'GyroZ']].copy()

# %%
conteos = chest['Timestamp'].value_counts()
print(conteos)
# Out:
# Timestamp
# 1555415336    112
# 1555415339    112
# 1555415332    112
# 1555415329    112
# 1555415343    112
#              ...
# 1555415464     98
# 1555415470     98
# 1555415469     98
# 1555415471     70
# 1555414552     14
# Name: count, Length: 148, dtype: int64

# %%
freq_2 = chest['Timestamp'].value_counts().mean()
freq_2
# Out:
# np.float64(100.93243243243244)

# %%
chest['Time'] = np.arange(len(chest))/freq_2 # numero de la muestra / frequencia 
#chest

# %%
A_2 = np.array([
    [1.002982,    9.415505E-05, 0.004346743],
    [9.04459E-05, 1.002731,   -0.001444198],
    [0.004346536, -0.001444751, 1.030587]
])

Acc_offset_2 = np.array([3.602701, -20.96658, 54.97186])
Gyro_offset_2 = np.array([-2.804399, 1.793105, 0.3411708])

Acc_raw_data_2 = chest[['AccX', 'AccY', 'AccZ']].values
Gyro_raw_data_2 = chest[['GyroX', 'GyroY', 'GyroZ']].values

Acc_calibrated_data_2 = (Acc_raw_data_2 - Acc_offset_2) @ A_2.T
Gyro_calibrated_data_2 = (Gyro_raw_data_2 - Gyro_offset_2)

chest[['AccX_cal', 'AccY_cal', 'AccZ_cal']] = Acc_calibrated_data_2
chest[['GyroX_cal', 'GyroY_cal', 'GyroZ_cal']] = Gyro_calibrated_data_2

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(16, 8))

ax1.plot(chest["AccX_cal"][:500])
ax2.plot(chest["AccY_cal"][:500])
ax3.plot(chest["AccZ_cal"][:500])

ax4.plot(chest["AccX_cal"][-500:])
ax5.plot(chest["AccY_cal"][-500:])
ax6.plot(chest["AccZ_cal"][-500:])

plt.show()

# %%
chest_clean = chest[200:-200].copy()
chest_clean = chest_clean.drop(['AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY',	'GyroZ'], axis=1)
chest_clean
# Out:
#         Timestamp        Time    AccX_cal   AccY_cal    AccZ_cal  GyroX_cal  \
# 200    1555415326    1.981524 -764.919134 -49.256973  646.009711   0.609277
# 201    1555415326    1.991431 -758.394340 -46.394597  655.337813   0.243423
# 202    1555415326    2.001339 -760.485133 -54.139326  638.492219   0.243423
# 203    1555415326    2.011246 -761.605034 -50.687298  662.999558   0.365375
# 204    1555415326    2.021154 -765.662105 -51.741695  629.476700   0.365375
# ...           ...         ...         ...        ...         ...        ...
# 14733  1555415469  145.968938 -774.505973 -21.412059  635.241063   0.853179
# 14734  1555415469  145.978846 -774.460142 -18.287359  631.527751   0.731228
# 14735  1555415469  145.988754 -774.979636 -13.445112  624.289100   0.121472
# 14736  1555415469  145.998661 -774.687135  -9.403508  621.015587  -0.366333
# 14737  1555415469  146.008569 -773.507421 -11.978214  625.173469  -0.610235
#
#        GyroY_cal  GyroZ_cal
# ...

# %%
chest_clean['Acc'] = np.sqrt(chest_clean['AccX_cal']**2 + chest_clean['AccY_cal']**2 + chest_clean['AccZ_cal']**2)
chest_clean['Gyro'] = np.sqrt(chest_clean['GyroX_cal']**2 + chest_clean['GyroY_cal']**2 + chest_clean['GyroZ_cal']**2)
chest_clean
# Out:
#         Timestamp        Time    AccX_cal   AccY_cal    AccZ_cal  GyroX_cal  \
# 200    1555415326    1.981524 -764.919134 -49.256973  646.009711   0.609277
# 201    1555415326    1.991431 -758.394340 -46.394597  655.337813   0.243423
# 202    1555415326    2.001339 -760.485133 -54.139326  638.492219   0.243423
# 203    1555415326    2.011246 -761.605034 -50.687298  662.999558   0.365375
# 204    1555415326    2.021154 -765.662105 -51.741695  629.476700   0.365375
# ...           ...         ...         ...        ...         ...        ...
# 14733  1555415469  145.968938 -774.505973 -21.412059  635.241063   0.853179
# 14734  1555415469  145.978846 -774.460142 -18.287359  631.527751   0.731228
# 14735  1555415469  145.988754 -774.979636 -13.445112  624.289100   0.121472
# 14736  1555415469  145.998661 -774.687135  -9.403508  621.015587  -0.366333
# 14737  1555415469  146.008569 -773.507421 -11.978214  625.173469  -0.610235
#
#        GyroY_cal  GyroZ_cal          Acc      Gyro
# ...

# %%
from scipy import fft

dt = 1/100

cs_fft = fft.fft(chest_clean['Acc'].values, axis=0)
freqs = fft.fftfreq(np.array(chest_clean['Acc']).size,d=dt)

#mask = (freqs > 0.5) & (freqs < 10)
mask = freqs > 0
f_plot = freqs[mask]
p_plot = np.abs(cs_fft[mask])

plt.plot(f_plot, p_plot, color='black')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.grid()
plt.show()

# %%
from scipy import fft

dt = 1/100
window_size = 10 

acc_smooth = moving_average(chest_clean['Acc'].values, window_size)

cs_fft = fft.fft(acc_smooth, axis=0)
freqs = fft.fftfreq(acc_smooth.size, d=dt)

mask = (freqs > 0) & (freqs < 10)
#mask = freqs > 0
f_plot = freqs[mask]
p_plot = np.abs(cs_fft[mask])

plt.plot(f_plot, p_plot)
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.grid()
plt.show()
